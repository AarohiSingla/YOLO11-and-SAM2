# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="E:/yolo11/SAM2_yolo11/demo/TumorDetection/data.yaml",  # path to dataset YAML
    epochs=20,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|█████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 11.0MB/s]
# New https://pypi.org/project/ultralytics/8.3.10 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5  Python-3.10.11 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: task=detect, mode=train, model=yolo11n.pt, data=E:/yolo11/SAM2_yolo11/demo/TumorDetection/data.yaml, epochs=20, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431647  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,815 parameters, 2,590,799 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed
# train: Scanning E:\yolo11\SAM2_yolo11\demo\TumorDetection\train\labels... 1370 images, 0 background
# train: WARNING  E:\yolo11\SAM2_yolo11\demo\TumorDetection\train\images\no_tumor_914_jpg.rf.6714544aee2bde5213fd2c366dff62aa.jpg: 1 duplicate labels removed
# train: New cache created: E:\yolo11\SAM2_yolo11\demo\TumorDetection\train\labels.cache
# WARNING  Box and segment counts should be equal, but got len(segments) = 1456, len(boxes) = 1461. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Scanning E:\yolo11\SAM2_yolo11\demo\TumorDetection\valid\labels... 395 images, 0 backgrounds,
# val: New cache created: E:\yolo11\SAM2_yolo11\demo\TumorDetection\valid\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.46G      0.918      3.047      1.269         22        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.915      0.244      0.404      0.277
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.39G     0.9197      1.986      1.246         17        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.593      0.484      0.469      0.312
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.39G      0.944      1.696      1.273         14        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.699      0.458      0.449       0.33
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.39G     0.9145       1.46      1.251         20        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.767      0.518      0.551       0.41
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.38G     0.8879      1.279      1.255         21        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.758       0.48      0.496      0.362
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.39G     0.8827      1.192      1.238         17        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.686      0.433      0.477      0.358
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.38G     0.8781      1.109      1.228         19        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.795      0.555      0.579      0.421
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.39G     0.8159      1.005      1.193         18        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.763      0.547       0.58      0.432
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.38G     0.8123     0.9877      1.202         29        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415       0.79      0.578      0.603      0.459
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.39G     0.8059     0.9412      1.187         23        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.757      0.566      0.565      0.436
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.48G     0.7194     0.9367      1.145         10        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.799      0.642      0.643      0.489
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.39G     0.6854     0.8339      1.129         11        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.838      0.609      0.634      0.494
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.38G     0.6605     0.7964      1.117         10        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.845      0.608      0.641      0.509
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.39G     0.6216     0.7505      1.095         11        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.809       0.61      0.631      0.502
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.38G      0.605     0.6884      1.069         11        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.825      0.635       0.64      0.506
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.39G     0.5921     0.6463       1.07         10        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.842      0.618      0.641       0.51
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.38G     0.5633     0.6243      1.041         12        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.842      0.606      0.651      0.527
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.39G     0.5663     0.6009      1.045         11        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.867      0.637      0.665      0.532
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.38G     0.5354     0.5647      1.027         10        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.827      0.654      0.662      0.544
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.39G     0.5219     0.5406      1.023         10        640: 100%|██████████| 86/
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.859      0.636      0.662      0.541
# 20 epochs completed in 0.059 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 5.5MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 5.5MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics 8.3.5  Python-3.10.11 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|████
#                    all        395        415      0.828      0.654      0.662      0.544
#               NO_tumor        115        116      0.912      0.981      0.966      0.815
#                 glioma         30         36      0.591      0.611      0.604      0.452
#             meningioma        144        148      0.929      0.912      0.945       0.82
#              pituitary        106        111      0.706      0.766      0.788      0.627
# space-occupying lesion-          1          4          1          0    0.00784    0.00525
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\train

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("test_images/meningioma_3.jpg", save=True)
results[0].show()
# Out:
# image 1/1 E:\yolo11\SAM2_yolo11\demo\test_images\meningioma_3.jpg: 640x640 1 meningioma, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# Load a model
model = YOLO("runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("test_images", save=True)
# Out:
# image 1/4 E:\yolo11\SAM2_yolo11\demo\test_images\glioma_2.jpg: 640x640 1 glioma, 27.0ms
# image 2/4 E:\yolo11\SAM2_yolo11\demo\test_images\meningioma_3.jpg: 640x640 1 meningioma, 17.0ms
# image 3/4 E:\yolo11\SAM2_yolo11\demo\test_images\no_tumor_1.jpg: 640x640 1 NO_tumor, 8.0ms
# image 4/4 E:\yolo11\SAM2_yolo11\demo\test_images\pituitary_5.jpg: 640x640 1 pituitary, 9.0ms
# Speed: 2.5ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("test_images/glioma_2.jpg")  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 E:\yolo11\SAM2_yolo11\demo\test_images\glioma_2.jpg: 640x640 1 glioma, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.7335], device='cuda:0')
# data: tensor([[273.8563, 421.1657, 314.7197, 444.7715,   0.7335,   1.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[294.2880, 432.9686,  40.8634,  23.6058]], device='cuda:0')
# xywhn: tensor([[0.4598, 0.6765, 0.0638, 0.0369]], device='cuda:0')
# xyxy: tensor([[273.8563, 421.1657, 314.7197, 444.7715]], device='cuda:0')
# xyxyn: tensor([[0.4279, 0.6581, 0.4917, 0.6950]], device='cuda:0')

# %%
from ultralytics import YOLO
from ultralytics import SAM

# Load the YOLO model
yolo_model = YOLO("runs/detect/train/weights/best.pt")  # pretrained YOLO model

# Run batched inference on a list of images
results = yolo_model("test_images/meningioma_3.jpg")  # return a list of Results objects

# Load the SAM model
sam_model = SAM("sam2_b.pt")

for result in results: 
     class_ids = result.boxes.cls.int().tolist()  # noqa 
     if len(class_ids): 
         boxes = result.boxes.xyxy  # Boxes object for bbox outputs 
         sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False, save=True, device=0)
# Out:
# image 1/1 E:\yolo11\SAM2_yolo11\demo\test_images\meningioma_3.jpg: 640x640 1 meningioma, 9.0ms
# Speed: 60.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/sam2_b.pt to 'sam2_b.pt'...
# 100%|███████████████████████████████████████████████████████████| 154M/154M [00:16<00:00, 9.97MB/s]
# Results saved to runs\segment\predict
# E:\yolo11\myvenv\lib\site-packages\ultralytics\models\sam\modules\blocks.py:569: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   x = F.scaled_dot_product_attention(
